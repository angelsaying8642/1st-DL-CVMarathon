# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101) # 建立101個值的陣列，在0到100之間平均分佈
y = (x_lin + np.random.randn(101) * 5) * w + b # np.random.randn:randn函数返回一个或一组样本，具有标准正态分布

plt.plot(x_lin, y, 'b.', label = 'data points') # b.:藍色點點
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE)) # %.3f:小數點後三位數字格式
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 189.7458
# The Mean absolute error is 10.914

# %% [markdown]
# # 作業二

# %%
'''
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

3. 蒐集而來的資料型態為何

4. 這組資料想解決的問題如何評估
'''
'''
1. 我選擇的是"New York City Airbnb Open Data"，airbnb是個知名的訂房網站，他可以透過比價或是其他篩選條件找出最適合的訂房專案，
   我想透過這份資料去了解訂購房型的趨勢以及消費者的需求
2. 資料的acknowledgements顯示，http://insideairbnb.com/ 可以從這個網址找到符合你需求的資料
3. 共有16個變數，有5個數值型態、5個文字型態、2個id和4個其他形態
4. 從inspiration可以看到以下：
What can we learn about different hosts and areas? => MSE
What can we learn from predictions? (ex: locations, prices, reviews, etc) =>可以用mse.mae去判斷預測準確率
Which hosts are the busiest and why? =>可以畫長條圖觀察
'''

# %% [markdown]
# # 作業三

# %%
'''
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

3. 蒐集而來的資料型態為何

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
'''
'''
1. 觀察近期間的營收如何，並針對里程數、離尖峰時段、區域、載客量以及最熱門的司機是誰，透過上述觀察，在做決策提升業績
2. 使用問卷調查了解乘客的回饋，並看會計和司機回報了解其他資訊並做整合
3. 區域和司機為類別型態，其他則為數值型態
4. 營收、離尖峰時段和載客量可以用折線圖來觀察並探索有沒有趨勢，司機跟區域可用長條圖表達，也可用散佈圖看營收和載客量是否有關聯，並用司機做分類
'''
